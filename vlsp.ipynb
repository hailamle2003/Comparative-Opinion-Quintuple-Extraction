# %%
# !pip install editdistance
# !pip install torch pytorch-lightning
# !pip install transformers tokenizers sentencepiece
# !pip install wandb
# Out:
# Collecting editdistance
#   Downloading editdistance-0.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: editdistance
# Successfully installed editdistance-0.6.2
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.0.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (2023.9.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (1.1.1)
# Requirement already satisfied: packaging>=17.1 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.1->pytorch-lightning) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.7.22)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.33.0)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.10/site-packages (0.13.3)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (0.1.99)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.15.9)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.31)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.30.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0)
# Requirement already satisfied: pathtools in /opt/conda/lib/python3.10/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (68.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# !pip install --upgrade wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.15.9)
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.31)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.30.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0)
# Requirement already satisfied: pathtools in /opt/conda/lib/python3.10/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (68.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Installing collected packages: wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.15.9
#     Uninstalling wandb-0.15.9:
#       Successfully uninstalled wandb-0.15.9
# Successfully installed wandb-0.15.12

# %%
import time
from torch.utils.data import Dataset
import os
import os
import logging
import time
import pickle
from tqdm import tqdm
import logging
import torch
from torch.utils.data import DataLoader
import pytorch_lightning as pl
from pytorch_lightning import seed_everything

from transformers import AdamW, MT5ForConditionalGeneration, AutoTokenizer
from transformers import get_linear_schedule_with_warmup

import re
import editdistance
import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import random

def preprocessing_data(path, is_valid=False):
  list_compare_quintuple = []
  for folder in os.listdir(path):
    with open(path + "/" + folder, "r", encoding="utf-8") as file:
        all_data = file.read()
        list_compare = all_data.split("\n\n")
        for i in range(len(list_compare)):
          list_compare_quintuple.append(list_compare[i].split('\n'))

  new_list_compare_quintuple = []
  for i in range(len(list_compare_quintuple)):
      if len(list_compare_quintuple[i]) == 3:
          new_list_compare_quintuple.append(list_compare_quintuple[i])
  list_compare_quintuple = new_list_compare_quintuple

  for i in range(len(list_compare_quintuple)):
      for j in range(len(list_compare_quintuple[i])):
          list_compare_quintuple[i][j] = list_compare_quintuple[i][j].lower()
  return list_compare_quintuple

# %%
def convert_list_to_string(list_):
    ###
    # ['16&&nâng', '17&&cấp', '18&&nhẹ']
    # => nâng cấp nhẹ
    ###
    string_ = ''
#     print(list_)
    for i in range(len(list_)):
        string_ += list_[i].split('&&')[1] + ' '
    if string_ == '':
        return 'unknow'
    return string_[:-1]

# %%
import json

# senttag2word = {
#     'com+': 'comparable and positive',
#     'eql': 'equal',
#     'com-': 'comparable and negative',
#     'sup+': 'superlative and positive',
#     'dif': 'different',
#     'com': 'comparable',
#     'sup-': 'superlative and negative',
#     'sup': 'superlative',
# }
def get_data_from_quin(list_compare_quintuple):


    sents = []
    targets = []
    for i in range(len(list_compare_quintuple)):
#         print(list_compare_quintuple[i])
        sents.append(list_compare_quintuple[i][0])
        target = ""
        for j in range(1, len(list_compare_quintuple[i])):
#             print("hi",list_compare_quintuple[i][j] )
#             print(list_compare_quintuple[i][j])
            json_data = json.loads(list_compare_quintuple[i][j])
#             targets.append(list_compare_quintuple[i][j])
            subject = convert_list_to_string(json_data['subject'])
            object = convert_list_to_string(json_data['object'])
            aspect = convert_list_to_string(json_data['aspect'])
            predicate = convert_list_to_string(json_data['predicate'])
            label = (json_data['label'])
            target +=  subject + " > " + object + " > " + aspect + " > " + predicate + ";" 
        targets.append(target.strip())
    return sents, targets

# %%
def read_data_from_path(path, is_valid):
    list_compare_quintuple = preprocessing_data(path, is_valid)
    sents, targets = get_data_from_quin(list_compare_quintuple)
    return sents, targets

# %%
sents, targets = read_data_from_path("/kaggle/input/dataset1/train", is_valid=False)

# %%
class ABSADataset(Dataset):
    def __init__(self, tokenizer, data_path, data_type, max_len=100, is_valid=False):
        # 'data/aste/rest16/train.txt'
        self.data_path = f'{data_path}/{data_type}'
        self.data_type = data_type
        self.max_len = max_len
        self.tokenizer = tokenizer

        self.inputs = []
        self.targets = []
        self.is_valid=is_valid
        self._build_examples()


    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, index):
        source_ids = self.inputs[index]["input_ids"].squeeze()
        target_ids = self.targets[index]["input_ids"].squeeze()

        src_mask = self.inputs[index]["attention_mask"].squeeze()      # might need to squeeze
        target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

        return {"source_ids": source_ids, "source_mask": src_mask,
                "target_ids": target_ids, "target_mask": target_mask}

    def _build_examples(self):

        inputs, targets = read_data_from_path(self.data_path, self.is_valid)

        for i in range(len(inputs)):

#             input = ' '.join(inputs[i])
            input = inputs[i]
            target = targets[i]


            tokenized_input = self.tokenizer.batch_encode_plus(
              [input], max_length=self.max_len, pad_to_max_length=True, truncation=True,
              return_tensors="pt",
            )
            tokenized_target = self.tokenizer.batch_encode_plus(
              [target], max_length=self.max_len, pad_to_max_length=True, truncation=True,
              return_tensors="pt"
            )

            self.inputs.append(tokenized_input)
            self.targets.append(tokenized_target)

# %%
class init_args:
    def __init__(self):
        self.data_path='/kaggle/input/dataset1/'
#         self.model_name_or_path='google/mt5-base'
        self.model_name_or_path='google/mt5-base'
        self.do_train=True
        self.do_direct_eval=True
        self.n_gpu='0'
        self.gradient_accumulation_steps=16
        self.learning_rate=2e-4
        self.num_train_epochs=15
        self.max_seq_length=128
        self.seed=42
        self.weight_decay=0.001
        self.adam_epsilon=1e-8
        self.warmup_steps=0
        self.num_workers=4

        self.batch_size=1

        if not os.path.exists('./outputs'):
            os.mkdir('./outputs')
        output_dir = f"./outputs"
        self.output_dir = output_dir

args = init_args()

# %%
def compute_f1_scores(predict_tuple, gold_tuple):
    """
    Function to compute F1 scores with pred and gold pairs/triplets
    The input needs to be already processed
    """
    # number of true postive, gold standard, predicted aspect terms
    n_tp, n_gold, n_pred = 0, 0, 0

    for i in range(len(predict_tuple)):
        n_gold += len(gold_tuple[i])
        n_pred += len(predict_tuple[i])

        for t in predict_tuple[i]:
            if t in gold_tuple[i]:
                n_tp += 1

    precision = float(n_tp) / float(n_pred) if n_pred != 0 else 0
    recall = float(n_tp) / float(n_gold) if n_gold != 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if precision != 0 or recall != 0 else 0
    scores = {'precision': precision, 'recall': recall, 'f1': f1}

    return scores

# %%
def recover_terms_with_editdistance(original_term, sent):
    words = original_term.split(' ')
    new_words = []
    for word in words:
        edit_dis = []
        for token in sent:
            edit_dis.append(editdistance.eval(word, token))
        smallest_idx = edit_dis.index(min(edit_dis))
        new_words.append(sent[smallest_idx])
    new_term = ' '.join(new_words)
    return new_term

def extract_spans_extraction(seq):
    extractions = []
#     print(seq)
    # if task == 'uabsa' and seq.lower() == 'none':
    #     return []
    # else:
    #     if task in ['uabsa', 'aope']:
            # all_pt = seq.split('; ')
            # for pt in all_pt:
            #     pt = pt[1:-1]
            #     try:
            #         a, b = pt.split(', ')
            #     except ValueError:
            #         a, b = '', ''
            #     extractions.append((a, b))
        # elif task in ['tasd', 'aste']:

    all_pt = seq.split(' ; ')
    for pt in all_pt:
        pt = pt[0:-0]
        try:
            a, b, c, d = pt.split(' > ')
            extractions.append((a, b, c, d))
        except ValueError:
            a, b, c, d, e = '', '', '', '', ''

    return extractions

def fix_preds_(all_pairs, sents):
    return all_pairs
    all_new_pairs = []


    for i, pairs in enumerate(all_pairs):
        new_pairs = []
        if pairs == []:
            all_new_pairs.append(pairs)
        else:
            print("*" * 100)
            print(pairs)
            print("*" * 100)
            for pair in pairs:
                #two formats have different orders
                p0, p1, p2, p3, p4 = pair
                # for annotation-type
                if p1 in sentiment_word_list:
                    at, ott, ac = p0, p2, p1
                    io_format = 'annotation'
                # for extraction type
                elif p2 in sentiment_word_list:
                    at, ott, ac = p0, p1, p2
                    io_format = 'extraction'

                #print(pair)
                # AT not in the original sentence
                if at not in  ' '.join(sents[i]):
                    # print('Issue')
                    new_at = recover_terms_with_editdistance(at, sents[i])
                else:
                    new_at = at

                if ac not in sentiment_word_list:
                    new_sentiment = recover_terms_with_editdistance(ac, sentiment_word_list)
                else:
                    new_sentiment = ac

                # OT not in the original sentence
                ots = ott.split(', ')
                new_ot_list = []
                for ot in ots:
                    if ot not in ' '.join(sents[i]):
                        # print('Issue')
                        new_ot_list.append(recover_terms_with_editdistance(ot, sents[i]))
                    else:
                        new_ot_list.append(ot)
                new_ot = ', '.join(new_ot_list)
                if io_format == 'extraction':
                    new_pairs.append((new_at, new_ot, new_sentiment))
                else:
                    new_pairs.append((new_at, new_sentiment, new_ot))
                # print(pair, '>>>>>', word_and_sentiment)
                # print(all_target_pairs[i])
            all_new_pairs.append(new_pairs)

    return all_new_pairs


def fix_pred_with_editdistance(all_predictions, sents):
    fixed_preds = fix_preds_(all_predictions, sents)
    return fixed_preds

# %%
def compute_scores(pred_seqs, gold_seqs, sents):
    """
    compute metrics for multiple tasks
    """
    assert len(pred_seqs) == len(gold_seqs)
    num_samples = len(gold_seqs)

    all_labels, all_predictions = [], []

    for i in range(num_samples):

        gold_list = extract_spans_extraction(gold_seqs[i])
        pred_list = extract_spans_extraction(pred_seqs[i])

        all_labels.append(gold_list)
        all_predictions.append(pred_list)

    print("\nResults of raw output")
    raw_scores = compute_f1_scores(all_predictions, all_labels)
    print(raw_scores)

    # fix the issues due to generation
    all_predictions_fixed = fix_pred_with_editdistance(all_predictions, sents)
    print("\nResults of fixed output")
    fixed_scores = compute_f1_scores(all_predictions_fixed, all_labels)
    print(fixed_scores)

    return raw_scores, fixed_scores, all_labels, all_predictions, all_predictions_fixed

# %%
def evaluate(data_loader, model, sents):
    """
    Compute scores given the predictions and gold labels
    """
    device = torch.device(f'cuda:{args.n_gpu}')
    model.model.to(device)

    model.model.eval()
    outputs, targets = [], []
    for batch in tqdm(data_loader):
        # need to push the data to device
        outs = model.model.generate(input_ids=batch['source_ids'].to(device),
                                    attention_mask=batch['source_mask'].to(device),
                                    max_length=args.max_seq_length)

        dec = [tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
        target = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch["target_ids"]]

        outputs.extend(dec)
        targets.extend(target)

    raw_scores, fixed_scores, all_labels, all_preds, all_preds_fixed = compute_scores(outputs, targets, sents)
    results = {'raw_scores': raw_scores, 'fixed_scores': fixed_scores, 'labels': all_labels,
               'preds': all_preds, 'preds_fixed': all_preds_fixed}
    # pickle.dump(results, open(f"{args.output_dir}/results-{args.task}-{args.dataset}-{args.paradigm}.pickle", 'wb'))

#     return raw_scores, fixed_scores
    return results

# %%
def return_answer(data_loader, model, sents):
    """
    Compute scores given the predictions and gold labels
    """
    device = torch.device(f'cuda:{args.n_gpu}')
    model.model.to(device)

    model.model.eval()
    outputs, targets = [], []
    for batch in tqdm(data_loader):
        # need to push the data to device
        outs = model.model.generate(input_ids=batch['source_ids'].to(device),
                                    attention_mask=batch['source_mask'].to(device),
                                    max_length=args.max_seq_length)

        dec = [tokenizer.decode(ids, skip_special_tokens=True) for ids in outs]
        target = [tokenizer.decode(ids, skip_special_tokens=True) for ids in batch["target_ids"]]

        outputs.extend(dec)
        targets.extend(target)

    return outputs, targets
#     raw_scores, fixed_scores, all_labels, all_preds, all_preds_fixed = compute_scores(outputs, targets, sents, paradigm, task)

# %%
logger = logging.getLogger(__name__)

# %%
def get_dataset(tokenizer, type_data, args):
    return ABSADataset(tokenizer=tokenizer, data_path=args.data_path, data_type=type_data, max_len=args.max_seq_length)

def get_dataset_valid(tokenizer, type_data, args, is_valid):
    return ABSADataset(tokenizer=tokenizer, data_path=args.data_path, data_type=type_data, max_len=args.max_seq_length, is_valid=is_valid)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
class T5FineTuner(pl.LightningModule):
    def __init__(self, hparams):
        super(T5FineTuner, self).__init__()

        for key in hparams.__dict__.keys():
            self.hparams[key]=hparams.__dict__[key]

        self.outputs = []
#         self.model = MT5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
        self.model = AutoModelForSeq2SeqLM.from_pretrained(hparams.model_name_or_path)
        self.tokenizer = AutoTokenizer.from_pretrained(hparams.model_name_or_path)

    def is_logger(self):
        return True

    def forward(self, input_ids, attention_mask=None, decoder_input_ids=None,
                decoder_attention_mask=None, labels=None):
        return self.model(
            input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            decoder_attention_mask=decoder_attention_mask,
            labels=labels,
        )

    def _step(self, batch):
        lm_labels = batch["target_ids"]
        lm_labels[lm_labels[:, :] == self.tokenizer.pad_token_id] = -100

        outputs = self(
            input_ids=batch["source_ids"],
            attention_mask=batch["source_mask"],
            labels=lm_labels,
            decoder_attention_mask=batch['target_mask']
        )

        loss = outputs[0]
        return loss

    def training_step(self, batch, batch_idx):
        loss = self._step(batch)

        tensorboard_logs = {"train_loss": loss}
        self.log('train_loss', loss, prog_bar=True)
        return {"loss": loss, "log": tensorboard_logs}

    def on_train_epoch_end(self):
        avg_train_loss = torch.stack(self.outputs).mean()
        tensorboard_logs = {"avg_train_loss": avg_train_loss}


        return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

    def validation_step(self, batch, batch_idx):
        loss = self._step(batch)
        self.outputs.append(loss)

        self.log('val_loss', loss, prog_bar=True)

        return {"val_loss": loss}


    def configure_optimizers(self):
        '''Prepare optimizer and schedule (linear warmup and decay)'''
        model = self.model
        no_decay = ["bias", "LayerNorm.weight"]
        optimizer_grouped_parameters = [
            {
                "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": self.hparams.weight_decay,
            },
            {
                "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
            },
        ]

        self.opt = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)



        self.opt2 = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.opt,
            mode='min',
            factor=0.95,
            patience=0,
            min_lr=1e-6,
            verbose=True
        )


#         return [self.opt], [self.opt2]
        return (
            {"optimizer": self.opt, "lr_scheduler": {"scheduler": self.opt2, "monitor": "val_loss"}}
        )

    def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure=None):
        optimizer.step(optimizer_idx)
        optimizer.zero_grad()
        self.lr_scheduler.step()

    def get_tqdm_dict(self):
        tqdm_dict = {"loss": "{:.4f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}
        return tqdm_dict

    def train_dataloader(self):
        print("load_dataset")
        train_dataset = get_dataset(tokenizer=self.tokenizer, type_data="train", args=self.hparams)
        dataloader = DataLoader(train_dataset, batch_size=self.hparams.batch_size, drop_last=True, shuffle=True, num_workers=self.hparams.num_workers)
        t_total = (
            (len(dataloader.dataset) // (self.hparams.batch_size * max(1, len(self.hparams.n_gpu))))
            // self.hparams.gradient_accumulation_steps
            * float(self.hparams.num_train_epochs)
        )
        scheduler = get_linear_schedule_with_warmup(
            self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
        )

        self.lr_scheduler = scheduler

        return dataloader

    def on_validation_epoch_end(self):

        avg_loss = torch.stack(self.outputs).mean()
        tensorboard_logs = {"val_loss": avg_loss}

#         self.train_dataloader()
        return {"avg_val_loss": avg_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}


    def val_dataloader(self):
        print("load_valid_dataset")
        val_dataset = get_dataset_valid(tokenizer=self.tokenizer, type_data="test", args=self.hparams, is_valid=True)
        return DataLoader(val_dataset, batch_size=self.hparams.batch_size, num_workers=self.hparams.num_workers)

# %%
class LoggingCallback(pl.Callback):
    def on_validation_end(self, trainer, pl_module):

        print("***** Validation results *****")
        if pl_module.is_logger():
            metrics = trainer.callback_metrics
        # Log results
        for key in sorted(metrics):
            if key not in ["log", "progress_bar"]:
#                 logger.info("{} = {}\n".format(key, str(metrics[key])))
                print("{} = {}\n".format(key, str(metrics[key])))

    def on_test_end(self, trainer, pl_module):
        print("***** Test results *****")

        if pl_module.is_logger():
            metrics = trainer.callback_metrics

        # Log and save results to file
#         output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
#         with open(output_test_results_file, "w") as writer:
        for key in sorted(metrics):
            if key not in ["log", "progress_bar"]:
                print("{} = {}\n".format(key, str(metrics[key])))
#                     writer.write("{} = {}\n".format(key, str(metrics[key])))

# %%
seed_everything(args.seed)

tokenizer = AutoTokenizer.from_pretrained(args.model_name_or_path)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. If you see this, DO NOT PANIC! This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
print("\n****** Conduct Training ******")
model = T5FineTuner(args)
# Out:
# ****** Conduct Training ******
# Downloading pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
import tensorflow as tf

checkpoint_callback = pl.callbacks.ModelCheckpoint(
        dirpath=args.output_dir, monitor='val_loss', mode='min', save_top_k=1, verbose=1)
earlyStopping= pl.callbacks.EarlyStopping(
        monitor='val_loss', patience=3, mode='min', min_delta=0.001, verbose=1)


train_params = dict(
        default_root_dir=args.output_dir,
        accumulate_grad_batches=args.gradient_accumulation_steps,
        gradient_clip_val=1.0,
        max_epochs=args.num_train_epochs,
        callbacks=[LoggingCallback(), checkpoint_callback, earlyStopping],
)

# %%
trainer = pl.Trainer(**train_params)
trainer.fit(model)
print("Finish training and saving the model!")
# Out:
# Sanity Checking: 0it [00:00, ?it/s]
# load_valid_dataset
# ***** Validation results *****
# val_loss = tensor(13.2052, device='cuda:0')
#
# load_dataset
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(10.6100, device='cuda:0')
#
# val_loss = tensor(2.9949, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(3.6973, device='cuda:0')
#
# val_loss = tensor(2.0336, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(2.7090, device='cuda:0')
#
# val_loss = tensor(1.3453, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(1.1468, device='cuda:0')
#
# val_loss = tensor(1.0035, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(1.0438, device='cuda:0')
#
# val_loss = tensor(0.7977, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.7888, device='cuda:0')
#
# val_loss = tensor(0.6545, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(1.0447, device='cuda:0')
#
# val_loss = tensor(0.6060, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.7100, device='cuda:0')
#
# val_loss = tensor(0.5311, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.6455, device='cuda:0')
#
# val_loss = tensor(0.5090, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.8102, device='cuda:0')
#
# val_loss = tensor(0.4752, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.7470, device='cuda:0')
#
# val_loss = tensor(0.4632, device='cuda:0')
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.8777, device='cuda:0')
#
# val_loss = tensor(0.4667, device='cuda:0')
#
# Epoch 00012: reducing learning rate of group 0 to 2.2800e-05.
# Epoch 00012: reducing learning rate of group 1 to 2.2800e-05.
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.7908, device='cuda:0')
#
# val_loss = tensor(0.4655, device='cuda:0')
#
# Epoch 00013: reducing learning rate of group 0 to 8.8667e-06.
# Epoch 00013: reducing learning rate of group 1 to 8.8667e-06.
# Validation: 0it [00:00, ?it/s]
# ***** Validation results *****
# train_loss = tensor(0.5794, device='cuda:0')
#
# val_loss = tensor(0.4638, device='cuda:0')
#
# Finish training and saving the model!

# %%
print("\n****** Conduct Evaluating ******")

    # model = T5FineTuner(args)
dev_results, test_results = {}, {}
best_f1, best_checkpoint, best_epoch = -999999.0, None, None
checkpoints=""

    # retrieve all the saved checkpoints for model selection
saved_model_dir = args.output_dir

for f in os.listdir(saved_model_dir):
    file_name = os.path.join(saved_model_dir, f)
    if 'ckpt' in file_name:
        checkpoints = file_name

print(f"We will perform validation on the following checkpoints: {checkpoints}")
# Out:
# ****** Conduct Evaluating ******
# We will perform validation on the following checkpoints: ./outputs/epoch=10-step=121.ckpt

# %%
tokenizer = AutoTokenizer.from_pretrained('google/mt5-base')
valid_dataset = ABSADataset(tokenizer, data_path=args.data_path, data_type='test',max_len=args.max_seq_length)
valid_loader = DataLoader(valid_dataset, batch_size=args.batch_size, num_workers=args.num_workers)

# test_dataset = ABSADataset(tokenizer, data_path=args.data_path, data_type='test', max_len=args.max_seq_length)
# test_loader = DataLoader(test_dataset, batch_size=args.batch_size, num_workers=args.num_workers)

# %%
model_ckpt = torch.load(checkpoints)

# %%
model.load_state_dict(model_ckpt['state_dict'])
# Out:
# <All keys matched successfully>

# %%
sents, _ = read_data_from_path(f'{args.data_path}/test', is_valid=True)

# %%
valid_result = evaluate(valid_loader, model, sents)
# Out:
# 100%|██████████| 82/82 [01:43<00:00,  1.26s/it]
# Results of raw output
# {'precision': 0, 'recall': 0, 'f1': 0}
#
# Results of fixed output
# {'precision': 0, 'recall': 0, 'f1': 0}

# %%
valid_answer, valid_gold = return_answer(valid_loader, model, sents)
# Out:
# 100%|██████████| 82/82 [01:41<00:00,  1.24s/it]

# %%
valid_answer
# Out:
# ['và kích thước màn hình > ngoài ra > kích thước > đáng chú ý;',
#  'xiaomi > galaxy > màn hình 6,8 inch > lớn hơn đáng kể;xiaomi > galaxy > galaxy > lớn hơn đáng kể;',
#  'galaxy > galaxy > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > c',
#  'samsung > cả hai điện thoại > hiệu suất thực tế > không đáng kể;samsung > cả hai điện thoại > unknow > hiệu suất thực tế > không đáng kể;',
#  'samsung > unknow > xung nhịp > cao hơn một chút;phiên bản snapdragon của samsung > unknow > xung nhịp > cao hơn một chút;',
#  'xiaomi 13 pro > unknow > khả năng thu phóng > tốt hơn;xiaomi 13 pro > unknow > unknow > hoạt động tốt hơn;',
#  'galaxy 13 pro > galaxy 13 pro > kích thước pin > lớn hơn gần 4%;galaxy 13 pro > galaxy 13 pro > viên pin 4.820 mah trên xiaomi 13 pro > lớn hơn gần 4%;',
#  'xiaomi > unknow > galaxy > đánh bại xiaomi trong trò chơi 3d > các bạn có thể thấy;xiaomi > unknow > galaxy > unknow > lợi thế rất lớn;',
#  'xiaomi > cả hai điện thoại > tốc độ 50w > nhanh hơn rất nhiều;xiaomi > cả hai điện thoại > tốc độ 50w > nhanh hơn rất nhiều;',
#  'các chiếc điện thoại này > phiên bản tiền nhiệm > được nâng cấp và cải thiện đáng kể;chiếc điện thoại này > phiên bản tiền nhiệm > được nâng cấp và cải thiện đáng kể;',
#  '<extra_id_0> > cổng sạc type c > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;cổng sạc type c > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;',
#  'các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > phần mềm không có khác biệt quá nhiều;các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > phần mềm không có khác biệt quá nhiều;',
#  'gpu > unknow > gpu > tốt hơn nhiều;gpu > unknow > gpu > tốt hơn nhiều;',
#  'ảnh 16mp > ảnh 16mp > chất lượng hình ảnh không chênh lệch nhiều;ảnh 16mp > ảnh 16mp > chất lượng hình ảnh không chênh lệch nhiều;',
#  'galaxy m31s > unknow > chênh lệch không nhiều;galaxy m31s > unknow > unknow > chênh lệch không nhiều;',
#  'sức mạnh camera > chính hơi kém cạnh một chút;bộ tứ camera > trang bị tương tự m31s > sức mạnh camera > chính hơi kém cạnh một chút;',
#  'lcd > unknow > hiển thị > không đẹp như amoled > unknow > tốc độ làm mới 90hz mượt mà hơn;unknow > unknow > hiển thị > không đẹp như amoled > unknow > tốc độ làm mới 90hz mượt mà hơn;',
#  'nó > m31s > pin > nhanh hơn một chút;m31s > pin > sạc > nhanh hơn một chút;',
#  'các thứ phải nhỏ hơn;iphone > unknow > mọi thứ phải nhỏ hơn;',
#  'những điện thoại tốt nhất hiện nay;cả hai điện thoại > tính năng mới > được đánh giá là một trong những điện thoại tốt nhất hiện nay;',
#  'galaxy s22 ultra > unknow > phân biệt > rất dễ nhận biết và phân biệt;galaxy s22 ultra > unknow > unknow > phân biệt;',
#  'các flagship hiện đại > hầu hết các flagship hiện đại > giắc cắm tai nghe > khe cắm thẻ nhớ microsd > giống như hầu hết các flagship hiện đại > giống như hầu hết các flagship hiện đại > giống như hầu hết các flagship hiện đại;cả hai > khe cắm thẻ nhớ microsd > giống như hầu hết các flagship hiện đ',
#  'samsung galaxy s22 ultra > samsung galaxy s22 ultra > phần rộng hơn;samsung galaxy s22 ultra > tỷ lệ khung hình > lớn hơn;',
#  'galaxy s22 ultra > unknow > không có nhiều thay đổi;galaxy s22 ultra > unknow > unknow > không có nhiều thay đổi;',
#  'các hình ảnh động mượt mà trên oneplus > unknow > hơi chập chờn hơn một chút;unknow > unknow > hơi chập chờn hơn một chút;',
#  'galaxy > unknow > hiệu suất gpu > thấp hơn;oneplus > unknow > unknow > các giá trị > thấp hơn;',
#  'galaxy > unknow > unknow > khảng thời gian > trong bài kiểm tra duyệt web nhẹ nhất;galaxy > unknow > unknow > khảng thời gian > trong bài kiểm tra duyệt web nhẹ nhất;',
#  'samsung 10 pro > unknow > tốc độ sạc nhanh và thời lượng pin > ưu thế đối;unknow > unknow > tốc độ sạc nhanh và thời lượng pin > ưu thế đối;',
#  'iphone xs max > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone',
#  'xs max > iphone 11 > lượng ram 4gb > mạnh hơn hẳn;iphone 11 > xs max > sử dùng ios cùng phiên bản;',
#  's21 plus > thiết kế “anh em ” với s21 plus > cảm giác cầm nắm tuyệt vời hơn;s21 plus > thiết kế “anh em ” với s21 plus > cảm giác cầm nắm tuyệt vời hơn;',
#  'galaxy s22 > s22 plus > galaxy s22 plus > khá khác biệt;galaxy s22 > s22 plus > galaxy s22 plus > những người tiền nhiệm năm 2021 > galaxy s22 plus > những người tiền nhiệm năm 2021 > galaxy s22 plus > những người tiền nhiệm năm 2021 > những người tiền nhiệm năm 2021 > những người tiền nhiệm năm 2021 > những',
#  'samsung > samsung > hiệu suất ánh sáng > yếu;samsung > cảm biến 50mp của s22 plus > kết quả > tốt hơn;',
#  's21 plus > s21 plus > phần cứng > tương tự như s21 plus > không có quá nhiều cải tiến;s21 plus > s21 plus > phần cứng > tương tự như s21 plus > tính năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > tương tự như s21 plus > ',
#  'galaxy a73 > unknow > nhìn cao cấp và hiện đại hơn;galaxy a73 > unknow > chỗ đặt camera trước > mỏng hơn;',
#  't1 > điện thoại a73 > tần số quét 120hz cao hơn;t1 > điện thoại a73 > tốc độ làm tươi > cao hơn;',
#  'samsung galaxy a73 > unknow > viên pin 5000 mah > cao hơn;samsung galaxy a73 > unknow > công suất sạc > cao hơn;',
#  '<extra_id_0> > unknow > chất liệu nhôm > dẫn nhiệt > tốt hơn;',
#  'samsung > unknow > công nghệ cao cấp hơn;samsung > unknow > unknow > công nghệ cao cấp hơn;',
#  'các điện thoại android > unknow > phần chiếm ưu thế hơn;iphone iphone 13 pro max > unknow > unknow > chiếm ưu thế hơn;',
#  'samsung > iphone > hệ điều hành > tiêu thụ pin > ít hơn;samsung > iphone > hệ điều hành > tiêu thụ pin > ổn hơn rất nhiều lần;',
#  'samsung > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều dài > không có quá nhiều sự khác biệt;',
#  'galaxy a03s > vivo y21 > trọng lượng > nặng hơn;galaxy a03s > vivo y21 > trọng lượng > nặng hơn;',
#  'các dòng điện thoại này > 2 dòng điện thoại này > màn hình của 2 dòng điện thoại này > đều giống nhau;',
#  '. 2 chipset > mediatek > đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều đến từ mediatek và đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu.',
#  'samsung galaxy a03s > samsung galaxy a03s > phần nhỉnh hơn;vivo y21 > samsung galaxy a03s > unknow > giá > cao hơn;',
#  'galaxy s10 5g > galaxy note 9 > diện mạo khá tinh tế;galaxy s10 5g > galaxy note 9 > diện mạo khá tinh tế;',
#  'galaxy note 9 > galaxy note 9 > kích thước > dày hơn;galaxy note 9 > galaxy note 9 > unknow > kích thước > dày hơn;',
#  ', chiếc điện thoại nhà táo khuyết > chiếc điện thoại nhà táo khuyết > ngâm nước sâu hơn;chiếc điện thoại nhà táo khuyết > chiếc điện thoại nhà táo khuyết > sâu hơn;',
#  'iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn google pixel 7a;iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn google pixel 7a;',
#  'samsung pixel 7a > iphone 13 > kích thước > lớn hơn;google pixel 7a > iphone 13 > màn hình > có kích thước > lớn hơn;',
#  'iphone 13 > iphone 13 > độ phân giải cao hơn rất nhiều;iphone 13 > iphone 13 > hệ thống camera trên google pixel 7 > độ phân giải cao hơn rất nhiều;',
#  'ios 16 > android 13 trên google pixel 7a > nhiều tính năng hấp dẫn hơn;iphone 13 > android 13 trên google pixel 7a > hệ điều hành ios 16 > nhiều tính năng hấp dẫn hơn;',
#  'galaxy z flip và z fold 2 > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế gi',
#  'các chiếc z fold 2 > cụm camera đôi của z flip > vẻ gọn gàng hơn;cụm camera đôi của z flip > cụm camera đôi của z flip > vẻ gọn gàng hơn;',
#  'các nhà sản xuất khác > unknow > unknow > không giống như các nhà sản xuất khác;google > unknow > unknow > không giống như các nhà sản xuất khác;',
#  'samsung > unknow > cảm giác cầm nắm bằng một tay thoải mái hơn;iphone 13 > unknow > unknow > unknow > cảm giác cầm nắm bằng một tay thoải mái hơn;',
#  'các đầu đọc dấu vân tay trong màn hình > tốc độ làm tươi cao hơn;đầu đọc dấu vân tay > trong màn hình > tốc độ làm tươi cao hơn;',
#  'huawei 12 > iphone 12 > khả năng chống bụi/nước > tốt hơn;iphone 12 > iphone 12 > unknow > chất liệu > tốt hơn;',
#  'xiaomi mi 11 > unknow > màn hình hiển thị > tốt hơn;xiaomi mi 11 > unknow > unknow > tấm nền > tốt hơn;',
#  'những vi xử lý thế hệ mới nhất hiện nay;cả hai model > hiệu năng > khá tương đồng nhau;',
#  'ios 14 > unknow > dung lượng ram > thấp hơn;iphone 12 > unknow > unknow > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu',
#  "Iphone 12 > unknow > dung lượng 2.815 mah >'lép vế'hơn hẳn đôi thủ của mình;iphone 12 > unknow > unknow >'lép vế'hơn hẳn đôi thủ của mình;",
#  'nếu xét tổng thể > iphone 12 > các thông số nhỏ hơn;iphone 12 > các thông số nhỏ hơn;',
#  '<extra_id_0> > unknow > những đối thủ ở cùng tầm giá > vượt trội;điện thoại > unknow > những thông số vượt trội;',
#  'galaxy a32 > camera trước > độ phân giải cao hơn 20 mp;galaxy a32 > camera trước > độ phân giải cao hơn 20 mp;',
#  'samsung galaxy j8 > samsung galaxy j8 > độ phân giải cao hơn;oppo f9 > samsung galaxy j8 > samsung galaxy j8 > kích thước màn hình > lớn hơn;',
#  'samsung j8 > samsung j8 > dung lượng > gấp đôi;oppo f9 > ram > gần như gấp đôi;',
#  'samsung j8 > unknow > thông số > gần bằng nhau;samsung j8 > unknow > thông số > gần bằng nhau;',
#  'các sản phẩm công nghệ hãng oppo > các sản phẩm công nghệ hãng oppo > camera trước > tốt hơn;các sản phẩm công nghệ hãng oppo > tài chính > tốt hơn;',
#  'galaxy a03s > bộ 3 camera đa chức năng có độ phân giải > thấp hơn;camera sau của galaxy a03s > bộ 3 camera đa chức năng có độ phân giải > thấp hơn;',
#  'samsung galaxy a13 4gb > samsung galaxy a03s > ram > lớn gấp đôi;samsung galaxy a13 4gb > samsung galaxy a03s > galaxy a03s > galaxy a03s > galaxy a03s > galaxy a03s > ram > lớn gấp đôi;',
#  '<extra_id_0> > unknow > cảm giác cầm nắm > trở nên thuận tiện hơn rất nhiều;',
#  'samsung galaxy s22 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > mạnh mẽ nhất của qualcomm > ở',
#  's22 > s22 > mức tiêu thụ điện là không giống nhau;s22 > s22 > thời gian sử dụng > ít hơn;',
#  'galaxy s22 > unknow > thời gian sạc > nhanh hơn;galaxy s22 > unknow > viên pin > có dung lượng thấp hơn;',
#  ', iphone 13 > thế hệ trước > kích thước nhỏ gọn hơn một chút;iphone 13 > iphone 13 > thế hệ trước > thiết kế mặt trước > kích thước nhỏ gọn hơn một chút;',
#  'các điện thoại này > cả hai điện thoại này > khung viền nhôm > được vát phẳng và mặt lưng kính bóng bẩy phía sau;cả hai điện thoại này > khung viền nhôm > được vát phẳng và mặt lưng kính bóng bẩy phía sau;',
#  'samsung > unknow > các bộ xử lý cao cấp nhất;samsung > unknow > unknow > các bộ xử lý cao cấp nhất;',
#  'samsung > cảm biến chính > kích thước > lớn hơn;iphone 13 của mình > khả năng nhiếp ảnh > cải thiện chất lượng ảnh thiếu sáng > tương tự;',
#  'galaxy s mới > iphone 14 pro max > lợi thế hơn;iphone 14 pro max > iphone 14 pro max > galaxy s mới > sạc đầy > mất nhiều thời gian hơn;',
#  'galaxy s23 + > galaxy s23 ultra > thời gian sạc > nhanh hơn;galaxy s23 ultra > galaxy s23 ultra > galaxy s23 ultra > thời gian sạc > nhanh hơn;']

# %%
valid_gold
# Out:
# ['unknow > unknow > kích thước > khác biệt đáng chú ý;unknow > unknow > kích thước màn hình > khác biệt đáng chú ý;',
#  'galaxy > xiaomi > màn hình > lớn hơn đáng kể;galaxy > xiaomi > tỷ lệ khung hình > rộng hơn;',
#  'cả hai > cả hai > máy quét dấu vân tay dưới màn hình > đều dựa vào;cả hai > cả hai > sinh trắc học > đều dựa vào máy quét dấu vân tay dưới màn hình;',
#  'cả hai điện thoại > cả hai điện thoại > bộ vi xử lý snapdragon 8 gen 2 của qualcomm > đều đi kèm;cả hai điện thoại > cả hai điện thoại > hiệu suất thực tế > sự khác biệt về hiệu suất thực tế là không đáng kể;',
#  'samsung > unknow > phiên bản snapdragon > xung nhịp cao hơn một chút;phiên bản snapdragon của samsung > unknow > xung nhịp > cao hơn một chút;',
#  'xiaomi 13 pro > galaxy > cảm biến máy ảnh chính > lớn hơn;xiaomi 13 pro > galaxy > cảm biến máy ảnh chính > hoạt động tốt hơn vào ban đêm;',
#  'xiaomi 13 pro > galaxy > kích thước pin > lớn hơn gần 4%;galaxy > xiaomi 13 pro > pin > dễ dàng giành chiến thắng;',
#  'galaxy > xiaomi > trò chơi 3d > đánh bại;xiaomi > galaxy > thời gian phát lại video youtube > có một lợi thế rất lớn;',
#  'cả hai điện thoại > cả hai điện thoại > sạc không dây > cũng hỗ trợ;xiaomi > galaxy > tốc độ > nhanh hơn rất nhiều;',
#  'chiếc điện thoại này > phiên bản tiền nhiệm > trải nghiệm xem phim > nâng cấp và cải thiện đáng kể;chiếc điện thoại này > phiên bản tiền nhiệm > chơi game > nâng cấp và cải thiện đáng kể;',
#  'cổng sạc type c > unknow > tốc độ sạc > nhanh hơn;cổng sạc type c > unknow > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;',
#  'unknow > các điện thoại samsung khác gần đây > phần mềm > không có khác biệt quá nhiều;unknow > những điện thoại của 2019 > phần mềm > không có khác biệt quá nhiều;',
#  'các đối thủ > unknow > gpu > tốt hơn nhiều;các đối thủ > unknow > mức giá > cùng;',
#  'unknow > ảnh 16mp > không gian lưu trữ > lớn hơn;unknow > ảnh 16mp > chất lượng hình ảnh > không chênh lệch nhiều;',
#  'galaxy m31s > những lựa chọn khác > mức giá > cùng;galaxy m31s > những lựa chọn khác > mức giá > chênh lệch không nhiều;',
#  'unknow > m31s > sức mạnh camera chính > hơi kém cạnh một chút;unknow > m31s > bộ tứ camera > tương tự;',
#  'một màn hình lcd > amoled > hiển thị > không đẹp như;unknow > unknow > tốc độ làm mới 90hz > mượt mà hơn;',
#  'nó > m31s > unknow > sạc nhanh hơn một chút;pin > m31s > unknow > không thể so sánh với;',
#  'iphone > unknow > unknow > nhỏ hơn;iphone > unknow > mọi thứ > nhỏ hơn;',
#  'cả hai điện thoại > cả hai điện thoại > hàng loạt tính năng mới > đều trang bị;cả hai điện thoại > unknow > unknow > điện thoại android tốt nhất;',
#  'galaxy s22 ultra > các đối thủ khác > thiết kế > dễ nhận biết và phân biệt;oneplus 10 pro > các đối thủ khác > unknow > dễ nhận biết và phân biệt;',
#  'cả hai > cả hai > giắc cắm tai nghe > đều không cung cấp;cả hai > cả hai > khe cắm thẻ nhớ microsd > đều không cung cấp;',
#  'samsung galaxy s22 ultra > unknow > tỷ lệ khung hình > có phần rộng hơn;samsung galaxy s22 ultra > unknow > diện tích hiển thị > lớn hơn;',
#  'galaxy s22 ultra > các mẫu máy tiền nhiệm của chúng > máy ảnh > không có nhiều thay đổi;oneplus 10 pro > các mẫu máy tiền nhiệm của chúng > máy ảnh > không có nhiều thay đổi;',
#  'nó > oneplus > phản ứng > chậm hơn một chút;nó > oneplus > hình ảnh động > hơi chập chờn hơn một chút;',
#  'galaxy > oneplus > bài kiểm tra 3d mark wildlife extreme kéo dài 20 phút > thấp hơn;oneplus > galaxy > chơi game > lợi thế hơn;',
#  'oneplus > galaxy > bài kiểm tra duyệt web nhẹ nhất > kéo dài gần như cùng một khoảng thời gian;unknow > unknow > chơi game 3d > kéo dài gần như cùng một khoảng thời gian;',
#  'oneplus 10 pro > unknow > tốc độ sạc nhanh > chiếm ưu thế;unknow > unknow > thời lượng pin > chiếm ưu thế;',
#  'iphone xs max > iphone 11 > màn hình > tốt hơn;iphone xs max > iphone 11 > màn hình tai thở > cùng sở hữu;',
#  'iphone 11 > iphone xs max > unknow > mạnh hơn hẳn;cả 2 > cả 2 > ram 4gb > cùng;',
#  's21 plus > unknow > cảm giác cầm nắm > tuyệt vời hơn;unknow > s21 plus > thiết kế > anh em;',
#  'galaxy s22 > những người tiền nhiệm năm 2021 > unknow > khá khác biệt;s22 plus > những người tiền nhiệm năm 2021 > unknow > khá khác biệt;',
#  'samsung > unknow > hiệu suất ánh sáng yếu > cải thiện;s22 plus > unknow > cảm biến 50mp > tốt hơn;',
#  'unknow > s21 plus > phần cứng > tương tự;unknow > s21 plus > tính năng ultrawide > không có quá nhiều cải tiến;',
#  'galaxy a73 > chiếc t1 5g > phần viền dưới các các viền xung quanh > mỏng hơn;galaxy a73 > màn hình dạng giọt nước đã " quá cổ " của chiếc t1 5g > unknow > cao cấp và hiện đại hơn;',
#  'điện thoại a73 > t1 > tốc độ làm tươi > thắng thế;nó > t1 > tần số quét > cao hơn;',
#  'samsung galaxy a73 > đối thủ > viên pin > cao hơn;samsung galaxy a73 > đối thủ > công suất sạc > không " có tuổi ";',
#  'chất liệu nhôm > unknow > dẫn nhiệt > tốt hơn;chất liệu nhôm > unknow > unknow > dễ nóng hơn;',
#  'iphone > đối thủ > phần này > phải " chào thua ";samsung > iphone > màn hình chính và phụ > công nghệ cao cấp hơn;',
#  'unknow > các điện thoại android > chip > " xịn xò " nhất;unknow > iphone iphone 13 pro max > chip > có phần chiếm ưu thế hơn;',
#  'samsung > iphone > pin > ổn hơn rất nhiều lần;samsung > iphone > hệ điều hành > tiêu thụ pin ít hơn;',
#  '2 dòng điện thoại đến từ 2 nhà samsung và vivo > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều dài > không có quá nhiều sự khác biệt;2 dòng điện thoại đến từ 2 nhà samsung và vivo > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều rộng > không có quá nhiều sự khác biệt;',
#  'galaxy a03s > vivo y21 > unknow > dày hơn;galaxy a03s > vivo y21 > trọng lượng > nặng hơn;',
#  'màn hình của 2 dòng điện thoại này > màn hình của 2 dòng điện thoại này > thông số cơ bản > đều giống nhau;2 dòng điện thoại này > 2 dòng điện thoại này > màn hình > đều giống nhau;',
#  '2 chipset được dùng cho 2 dòng máy này > 2 chipset được dùng cho 2 dòng máy này > unknow > đều đến từ mediatek;2 chipset được dùng cho 2 dòng máy này > 2 chipset được dùng cho 2 dòng máy này > 8 lõi cpu > đều có;',
#  'vivo y21 > samsung galaxy a03s > unknow > nhỉnh hơn;sản phẩm > samsung galaxy a03s > giá > cao hơn;',
#  'galaxy s10 5g > galaxy note 9 > unknow > đều là những sản phẩm hàng đầu của samsung;unknow > unknow > diện mạo khá tinh tế, sang trọng > đều sở hữu;',
#  'galaxy note 9 > unknow > đánh giá > cao hơn;sản phẩm này > unknow > kích thước > dày hơn;',
#  'chiếc điện thoại nhà táo khuyết > unknow > ngâm nước > sâu hơn;chiếc điện thoại nhà táo khuyết > unknow > ngâm nước > lâu hơn;',
#  'màn hình iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn;iphone 13 > google pixel 7a > màn hình > chất lượng hiển thị tốt hơn;',
#  'màn hình chiếc flagship của google > iphone 13 > kích thước > lớn hơn;chiếc flagship của google > iphone 13 > màn hình > kích thước lớn hơn;',
#  'google pixel 7 > iphone 13 > hệ thống camera > độ phân giải cao hơn rất nhiều;hệ thống camera trên google pixel 7 > iphone 13 > độ phân giải > cao hơn rất nhiều;',
#  'hệ điều hành ios 16 > android 13 > tính năng > hấp dẫn hơn;iphone 13 > google pixel 7a > hệ điều hành > nhiều tính năng hấp dẫn hơn;',
#  'galaxy z flip > phần còn lại của thế giới smartphone > unknow > khác hẳn;z fold 2 > phần còn lại của thế giới smartphone > unknow > khác hẳn;',
#  'z flip > z fold 2 > cụm camera đôi > gọn gàng hơn;z flip > z fold 2 > cụm camera đôi > không “ bành chướng ” như;',
#  'google > iphone > mô-đun camera > hoàn toàn khác;google > các nhà sản xuất khác > unknow > không giống;',
#  'iphone 13 > pixel 6 > unknow > nhỏ gọn hơn;iphone 13 > pixel 6 > cảm giác cầm nắm bằng một tay > thoải mái hơn;',
#  'unknow > unknow > tốc độ làm tươi > cao hơn;unknow > unknow > kích thước > lớn hơn;',
#  'iphone 12 > mi 11 > chất liệu > độ bền tốt hơn;chất liệu trên iphone 12 > unknow > độ bền > tốt hơn;',
#  'xiaomi mi 11 > unknow > màn hình hiển thị > tốt hơn;xiaomi mi 11 > unknow > tấm nền > tốt nhất trên thị trường hiện nay;',
#  'cả hai model > cả hai model > những vi xử lý thế hệ mới nhất hiện nay > đều được nhà sản xuất trang bị;cả hai model > cả hai model > hiệu năng > khá tương đồng nhau;',
#  'iphone 12 > đối thủ của nó > dung lượng lượng ram > thấp hơn;iphone 12 > đối thủ của nó > hiệu suất > tương đương;',
#  "iphone 12 > đôi thủ của mình > viên pin >'lép vế'hơn hẳn;viên pin của iphone 12 > đôi thủ của mình > dung lượng >'lép vế'hơn hẳn;",
#  'iphone 12 > mi 11 > màn hình > các thông số nhỏ hơn;iphone 12 > mi 11 > lượng tiêu hao năng lượng > ít hơn;',
#  'điện thoại > những đối thủ ở cùng tầm giá > thông số > vượt trội;điện thoại > những đối thủ ở cùng tầm giá > unknow > được đánh giá cao so với;',
#  'galaxy a32 > galaxy a33 > camera trước > có phần nhỉnh hơn;galaxy a32 > unknow > độ phân giải > cao hơn;',
#  'oppo f9 > samsung galaxy j8 > kích thước màn hình > lớn hơn;oppo f9 > samsung galaxy j8 > độ phân giải > cao hơn;',
#  'oppo f9 > samsung j8 > ram > gần như gấp đôi dung lượng;oppo f9 > samsung j8 > rom > gần như gấp đôi dung lượng;',
#  'oppo f9 > samsung j8 > thiết kế camera kép ở phía sau > đều được;oppo f9 > samsung j8 > thông số > gần bằng nhau;',
#  'các các sản phẩm công nghệ hãng oppo > unknow > cấu hình > cao hơn;các các sản phẩm công nghệ hãng oppo > unknow > camera trước > tốt hơn;',
#  'galaxy a03s > unknow > camera sau > độ phân giải thấp hơn;camera sau của galaxy a03s > unknow > độ phân giải > thấp hơn;',
#  'samsung galaxy a13 4gb > samsung galaxy a03s > ram 4 gb > đều có;galaxy a13 4gb > galaxy a03s > rom > lớn gấp đôi;',
#  'unknow > unknow > cảm giác cầm nắm > thuận tiện hơn rất nhiều;unknow > unknow > sử dụng một tay > thuận tiện hơn rất nhiều;',
#  'samsung galaxy s22 > unknow > con chip > mạnh mẽ nhất của qualcomm ở thời điểm hiện tại;snapdragon 8 gen 1 > unknow > unknow > mạnh mẽ nhất của qualcomm ở thời điểm hiện tại;',
#  's22 > unknow > thời gian sử dụng > không có nghĩa là thời gian sử dụng của s22 sẽ ít hơn;s22 > unknow > mức tiêu thụ điện > không giống nhau;',
#  'galaxy s22 > unknow > viên pin > dung lượng thấp hơn;galaxy s22 > unknow > thời gian sạc > nhanh hơn;',
#  'iphone 13 > thế hệ trước > thiết kế mặt trước > cải tiến nhỏ;iphone 13 > thế hệ trước > phần notch > kích thước nhỏ gọn hơn một chút;',
#  'cả hai điện thoại này > cả hai điện thoại này > khung viền nhôm được vát phẳng > đều sở hữu;cả hai điện thoại này > cả hai điện thoại này > mặt lưng kính bóng bẩy phía sau > đều sở hữu;',
#  'mẫu điện thoại cao cấp tiếp theo của samsung > unknow > bộ xử lý > cao cấp nhất qualcomm ở thời điểm hiện tại;snapdragon 8 gen 2 > unknow > unknow > cao cấp nhất qualcomm ở thời điểm hiện tại;',
#  'iphone 13 > thế hệ trước > hệ thống camera kép > tương tự;iphone 13 > thế hệ trước > cảm biến chính > kích thước lớn hơn;',
#  'galaxy s mới > iphone 14 pro > sạc có dây > lợi thế hơn;galaxy s mới > iphone 14 pro > sạc có dây > lợi thế hơn;',
#  'unknow > galaxy s23 + > thời gian sạc > nhanh hơn;unknow > galaxy s23 ultra > thời gian sạc > nhanh hơn;']

# %%
def compare(val_answer, val_gold):
    count = 0
    count1 = 0
    for i in range(len(val_answer)):
        if(val_answer[i] != val_gold[i]):    
            print(val_answer[i])
            print('---------')
            print(val_gold[i])
            count+=1
        else:
            count1 +=1
        print('=====')
    print(count, count1)

# %%
compare(valid_answer, valid_gold)
# Out:
# và kích thước màn hình > ngoài ra > kích thước > đáng chú ý;
# ---------
# unknow > unknow > kích thước > khác biệt đáng chú ý;unknow > unknow > kích thước màn hình > khác biệt đáng chú ý;
# =====
# xiaomi > galaxy > màn hình 6,8 inch > lớn hơn đáng kể;xiaomi > galaxy > galaxy > lớn hơn đáng kể;
# ---------
# galaxy > xiaomi > màn hình > lớn hơn đáng kể;galaxy > xiaomi > tỷ lệ khung hình > rộng hơn;
# =====
# galaxy > galaxy > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > cả hai > c
# ---------
# cả hai > cả hai > máy quét dấu vân tay dưới màn hình > đều dựa vào;cả hai > cả hai > sinh trắc học > đều dựa vào máy quét dấu vân tay dưới màn hình;
# =====
# samsung > cả hai điện thoại > hiệu suất thực tế > không đáng kể;samsung > cả hai điện thoại > unknow > hiệu suất thực tế > không đáng kể;
# ---------
# cả hai điện thoại > cả hai điện thoại > bộ vi xử lý snapdragon 8 gen 2 của qualcomm > đều đi kèm;cả hai điện thoại > cả hai điện thoại > hiệu suất thực tế > sự khác biệt về hiệu suất thực tế là không đáng kể;
# =====
# samsung > unknow > xung nhịp > cao hơn một chút;phiên bản snapdragon của samsung > unknow > xung nhịp > cao hơn một chút;
# ---------
# samsung > unknow > phiên bản snapdragon > xung nhịp cao hơn một chút;phiên bản snapdragon của samsung > unknow > xung nhịp > cao hơn một chút;
# =====
# xiaomi 13 pro > unknow > khả năng thu phóng > tốt hơn;xiaomi 13 pro > unknow > unknow > hoạt động tốt hơn;
# ---------
# xiaomi 13 pro > galaxy > cảm biến máy ảnh chính > lớn hơn;xiaomi 13 pro > galaxy > cảm biến máy ảnh chính > hoạt động tốt hơn vào ban đêm;
# =====
# galaxy 13 pro > galaxy 13 pro > kích thước pin > lớn hơn gần 4%;galaxy 13 pro > galaxy 13 pro > viên pin 4.820 mah trên xiaomi 13 pro > lớn hơn gần 4%;
# ---------
# xiaomi 13 pro > galaxy > kích thước pin > lớn hơn gần 4%;galaxy > xiaomi 13 pro > pin > dễ dàng giành chiến thắng;
# =====
# xiaomi > unknow > galaxy > đánh bại xiaomi trong trò chơi 3d > các bạn có thể thấy;xiaomi > unknow > galaxy > unknow > lợi thế rất lớn;
# ---------
# galaxy > xiaomi > trò chơi 3d > đánh bại;xiaomi > galaxy > thời gian phát lại video youtube > có một lợi thế rất lớn;
# =====
# xiaomi > cả hai điện thoại > tốc độ 50w > nhanh hơn rất nhiều;xiaomi > cả hai điện thoại > tốc độ 50w > nhanh hơn rất nhiều;
# ---------
# cả hai điện thoại > cả hai điện thoại > sạc không dây > cũng hỗ trợ;xiaomi > galaxy > tốc độ > nhanh hơn rất nhiều;
# =====
# các chiếc điện thoại này > phiên bản tiền nhiệm > được nâng cấp và cải thiện đáng kể;chiếc điện thoại này > phiên bản tiền nhiệm > được nâng cấp và cải thiện đáng kể;
# ---------
# chiếc điện thoại này > phiên bản tiền nhiệm > trải nghiệm xem phim > nâng cấp và cải thiện đáng kể;chiếc điện thoại này > phiên bản tiền nhiệm > chơi game > nâng cấp và cải thiện đáng kể;
# =====
# <extra_id_0> > cổng sạc type c > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;cổng sạc type c > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;
# ---------
# cổng sạc type c > unknow > tốc độ sạc > nhanh hơn;cổng sạc type c > unknow > khả năng truyền tải dữ liệu > nhanh chóng và hiệu quả hơn;
# =====
# các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > phần mềm không có khác biệt quá nhiều;các điện thoại samsung khác gần đây hay cả những điện thoại của 2019 > phần mềm không có khác biệt quá nhiều;
# ---------
# unknow > các điện thoại samsung khác gần đây > phần mềm > không có khác biệt quá nhiều;unknow > những điện thoại của 2019 > phần mềm > không có khác biệt quá nhiều;
# =====
# gpu > unknow > gpu > tốt hơn nhiều;gpu > unknow > gpu > tốt hơn nhiều;
# ---------
# các đối thủ > unknow > gpu > tốt hơn nhiều;các đối thủ > unknow > mức giá > cùng;
# =====
# ảnh 16mp > ảnh 16mp > chất lượng hình ảnh không chênh lệch nhiều;ảnh 16mp > ảnh 16mp > chất lượng hình ảnh không chênh lệch nhiều;
# ---------
# unknow > ảnh 16mp > không gian lưu trữ > lớn hơn;unknow > ảnh 16mp > chất lượng hình ảnh > không chênh lệch nhiều;
# =====
# galaxy m31s > unknow > chênh lệch không nhiều;galaxy m31s > unknow > unknow > chênh lệch không nhiều;
# ---------
# galaxy m31s > những lựa chọn khác > mức giá > cùng;galaxy m31s > những lựa chọn khác > mức giá > chênh lệch không nhiều;
# =====
# sức mạnh camera > chính hơi kém cạnh một chút;bộ tứ camera > trang bị tương tự m31s > sức mạnh camera > chính hơi kém cạnh một chút;
# ---------
# unknow > m31s > sức mạnh camera chính > hơi kém cạnh một chút;unknow > m31s > bộ tứ camera > tương tự;
# =====
# lcd > unknow > hiển thị > không đẹp như amoled > unknow > tốc độ làm mới 90hz mượt mà hơn;unknow > unknow > hiển thị > không đẹp như amoled > unknow > tốc độ làm mới 90hz mượt mà hơn;
# ---------
# một màn hình lcd > amoled > hiển thị > không đẹp như;unknow > unknow > tốc độ làm mới 90hz > mượt mà hơn;
# =====
# nó > m31s > pin > nhanh hơn một chút;m31s > pin > sạc > nhanh hơn một chút;
# ---------
# nó > m31s > unknow > sạc nhanh hơn một chút;pin > m31s > unknow > không thể so sánh với;
# =====
# các thứ phải nhỏ hơn;iphone > unknow > mọi thứ phải nhỏ hơn;
# ---------
# iphone > unknow > unknow > nhỏ hơn;iphone > unknow > mọi thứ > nhỏ hơn;
# =====
# những điện thoại tốt nhất hiện nay;cả hai điện thoại > tính năng mới > được đánh giá là một trong những điện thoại tốt nhất hiện nay;
# ---------
# cả hai điện thoại > cả hai điện thoại > hàng loạt tính năng mới > đều trang bị;cả hai điện thoại > unknow > unknow > điện thoại android tốt nhất;
# =====
# galaxy s22 ultra > unknow > phân biệt > rất dễ nhận biết và phân biệt;galaxy s22 ultra > unknow > unknow > phân biệt;
# ---------
# galaxy s22 ultra > các đối thủ khác > thiết kế > dễ nhận biết và phân biệt;oneplus 10 pro > các đối thủ khác > unknow > dễ nhận biết và phân biệt;
# =====
# các flagship hiện đại > hầu hết các flagship hiện đại > giắc cắm tai nghe > khe cắm thẻ nhớ microsd > giống như hầu hết các flagship hiện đại > giống như hầu hết các flagship hiện đại > giống như hầu hết các flagship hiện đại;cả hai > khe cắm thẻ nhớ microsd > giống như hầu hết các flagship hiện đ
# ---------
# cả hai > cả hai > giắc cắm tai nghe > đều không cung cấp;cả hai > cả hai > khe cắm thẻ nhớ microsd > đều không cung cấp;
# =====
# samsung galaxy s22 ultra > samsung galaxy s22 ultra > phần rộng hơn;samsung galaxy s22 ultra > tỷ lệ khung hình > lớn hơn;
# ---------
# samsung galaxy s22 ultra > unknow > tỷ lệ khung hình > có phần rộng hơn;samsung galaxy s22 ultra > unknow > diện tích hiển thị > lớn hơn;
# =====
# galaxy s22 ultra > unknow > không có nhiều thay đổi;galaxy s22 ultra > unknow > unknow > không có nhiều thay đổi;
# ---------
# galaxy s22 ultra > các mẫu máy tiền nhiệm của chúng > máy ảnh > không có nhiều thay đổi;oneplus 10 pro > các mẫu máy tiền nhiệm của chúng > máy ảnh > không có nhiều thay đổi;
# =====
# các hình ảnh động mượt mà trên oneplus > unknow > hơi chập chờn hơn một chút;unknow > unknow > hơi chập chờn hơn một chút;
# ---------
# nó > oneplus > phản ứng > chậm hơn một chút;nó > oneplus > hình ảnh động > hơi chập chờn hơn một chút;
# =====
# galaxy > unknow > hiệu suất gpu > thấp hơn;oneplus > unknow > unknow > các giá trị > thấp hơn;
# ---------
# galaxy > oneplus > bài kiểm tra 3d mark wildlife extreme kéo dài 20 phút > thấp hơn;oneplus > galaxy > chơi game > lợi thế hơn;
# =====
# galaxy > unknow > unknow > khảng thời gian > trong bài kiểm tra duyệt web nhẹ nhất;galaxy > unknow > unknow > khảng thời gian > trong bài kiểm tra duyệt web nhẹ nhất;
# ---------
# oneplus > galaxy > bài kiểm tra duyệt web nhẹ nhất > kéo dài gần như cùng một khoảng thời gian;unknow > unknow > chơi game 3d > kéo dài gần như cùng một khoảng thời gian;
# =====
# samsung 10 pro > unknow > tốc độ sạc nhanh và thời lượng pin > ưu thế đối;unknow > unknow > tốc độ sạc nhanh và thời lượng pin > ưu thế đối;
# ---------
# oneplus 10 pro > unknow > tốc độ sạc nhanh > chiếm ưu thế;unknow > unknow > thời lượng pin > chiếm ưu thế;
# =====
# iphone xs max > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone xs max > màn hình > tốt hơn iphone 11 > iphone
# ---------
# iphone xs max > iphone 11 > màn hình > tốt hơn;iphone xs max > iphone 11 > màn hình tai thở > cùng sở hữu;
# =====
# xs max > iphone 11 > lượng ram 4gb > mạnh hơn hẳn;iphone 11 > xs max > sử dùng ios cùng phiên bản;
# ---------
# iphone 11 > iphone xs max > unknow > mạnh hơn hẳn;cả 2 > cả 2 > ram 4gb > cùng;
# =====
# s21 plus > thiết kế “anh em ” với s21 plus > cảm giác cầm nắm tuyệt vời hơn;s21 plus > thiết kế “anh em ” với s21 plus > cảm giác cầm nắm tuyệt vời hơn;
# ---------
# s21 plus > unknow > cảm giác cầm nắm > tuyệt vời hơn;unknow > s21 plus > thiết kế > anh em;
# =====
# galaxy s22 > s22 plus > galaxy s22 plus > khá khác biệt;galaxy s22 > s22 plus > galaxy s22 plus > những người tiền nhiệm năm 2021 > galaxy s22 plus > những người tiền nhiệm năm 2021 > galaxy s22 plus > những người tiền nhiệm năm 2021 > những người tiền nhiệm năm 2021 > những người tiền nhiệm năm 2021 > những
# ---------
# galaxy s22 > những người tiền nhiệm năm 2021 > unknow > khá khác biệt;s22 plus > những người tiền nhiệm năm 2021 > unknow > khá khác biệt;
# =====
# samsung > samsung > hiệu suất ánh sáng > yếu;samsung > cảm biến 50mp của s22 plus > kết quả > tốt hơn;
# ---------
# samsung > unknow > hiệu suất ánh sáng yếu > cải thiện;s22 plus > unknow > cảm biến 50mp > tốt hơn;
# =====
# s21 plus > s21 plus > phần cứng > tương tự như s21 plus > không có quá nhiều cải tiến;s21 plus > s21 plus > phần cứng > tương tự như s21 plus > tính năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > năng ultrawide > tương tự như s21 plus >
# ---------
# unknow > s21 plus > phần cứng > tương tự;unknow > s21 plus > tính năng ultrawide > không có quá nhiều cải tiến;
# =====
# galaxy a73 > unknow > nhìn cao cấp và hiện đại hơn;galaxy a73 > unknow > chỗ đặt camera trước > mỏng hơn;
# ---------
# galaxy a73 > chiếc t1 5g > phần viền dưới các các viền xung quanh > mỏng hơn;galaxy a73 > màn hình dạng giọt nước đã " quá cổ " của chiếc t1 5g > unknow > cao cấp và hiện đại hơn;
# =====
# t1 > điện thoại a73 > tần số quét 120hz cao hơn;t1 > điện thoại a73 > tốc độ làm tươi > cao hơn;
# ---------
# điện thoại a73 > t1 > tốc độ làm tươi > thắng thế;nó > t1 > tần số quét > cao hơn;
# =====
# samsung galaxy a73 > unknow > viên pin 5000 mah > cao hơn;samsung galaxy a73 > unknow > công suất sạc > cao hơn;
# ---------
# samsung galaxy a73 > đối thủ > viên pin > cao hơn;samsung galaxy a73 > đối thủ > công suất sạc > không " có tuổi ";
# =====
# <extra_id_0> > unknow > chất liệu nhôm > dẫn nhiệt > tốt hơn;
# ---------
# chất liệu nhôm > unknow > dẫn nhiệt > tốt hơn;chất liệu nhôm > unknow > unknow > dễ nóng hơn;
# =====
# samsung > unknow > công nghệ cao cấp hơn;samsung > unknow > unknow > công nghệ cao cấp hơn;
# ---------
# iphone > đối thủ > phần này > phải " chào thua ";samsung > iphone > màn hình chính và phụ > công nghệ cao cấp hơn;
# =====
# các điện thoại android > unknow > phần chiếm ưu thế hơn;iphone iphone 13 pro max > unknow > unknow > chiếm ưu thế hơn;
# ---------
# unknow > các điện thoại android > chip > " xịn xò " nhất;unknow > iphone iphone 13 pro max > chip > có phần chiếm ưu thế hơn;
# =====
# samsung > iphone > hệ điều hành > tiêu thụ pin > ít hơn;samsung > iphone > hệ điều hành > tiêu thụ pin > ổn hơn rất nhiều lần;
# ---------
# samsung > iphone > pin > ổn hơn rất nhiều lần;samsung > iphone > hệ điều hành > tiêu thụ pin ít hơn;
# =====
# samsung > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều dài > không có quá nhiều sự khác biệt;
# ---------
# 2 dòng điện thoại đến từ 2 nhà samsung và vivo > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều dài > không có quá nhiều sự khác biệt;2 dòng điện thoại đến từ 2 nhà samsung và vivo > 2 dòng điện thoại đến từ 2 nhà samsung và vivo > chiều rộng > không có quá nhiều sự khác biệt;
# =====
# galaxy a03s > vivo y21 > trọng lượng > nặng hơn;galaxy a03s > vivo y21 > trọng lượng > nặng hơn;
# ---------
# galaxy a03s > vivo y21 > unknow > dày hơn;galaxy a03s > vivo y21 > trọng lượng > nặng hơn;
# =====
# các dòng điện thoại này > 2 dòng điện thoại này > màn hình của 2 dòng điện thoại này > đều giống nhau;
# ---------
# màn hình của 2 dòng điện thoại này > màn hình của 2 dòng điện thoại này > thông số cơ bản > đều giống nhau;2 dòng điện thoại này > 2 dòng điện thoại này > màn hình > đều giống nhau;
# =====
# . 2 chipset > mediatek > đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều đến từ mediatek và đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu. 2 chipset > được dùng cho 2 dòng máy này đều có 8 lõi cpu.
# ---------
# 2 chipset được dùng cho 2 dòng máy này > 2 chipset được dùng cho 2 dòng máy này > unknow > đều đến từ mediatek;2 chipset được dùng cho 2 dòng máy này > 2 chipset được dùng cho 2 dòng máy này > 8 lõi cpu > đều có;
# =====
# samsung galaxy a03s > samsung galaxy a03s > phần nhỉnh hơn;vivo y21 > samsung galaxy a03s > unknow > giá > cao hơn;
# ---------
# vivo y21 > samsung galaxy a03s > unknow > nhỉnh hơn;sản phẩm > samsung galaxy a03s > giá > cao hơn;
# =====
# galaxy s10 5g > galaxy note 9 > diện mạo khá tinh tế;galaxy s10 5g > galaxy note 9 > diện mạo khá tinh tế;
# ---------
# galaxy s10 5g > galaxy note 9 > unknow > đều là những sản phẩm hàng đầu của samsung;unknow > unknow > diện mạo khá tinh tế, sang trọng > đều sở hữu;
# =====
# galaxy note 9 > galaxy note 9 > kích thước > dày hơn;galaxy note 9 > galaxy note 9 > unknow > kích thước > dày hơn;
# ---------
# galaxy note 9 > unknow > đánh giá > cao hơn;sản phẩm này > unknow > kích thước > dày hơn;
# =====
# , chiếc điện thoại nhà táo khuyết > chiếc điện thoại nhà táo khuyết > ngâm nước sâu hơn;chiếc điện thoại nhà táo khuyết > chiếc điện thoại nhà táo khuyết > sâu hơn;
# ---------
# chiếc điện thoại nhà táo khuyết > unknow > ngâm nước > sâu hơn;chiếc điện thoại nhà táo khuyết > unknow > ngâm nước > lâu hơn;
# =====
# iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn google pixel 7a;iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn google pixel 7a;
# ---------
# màn hình iphone 13 > google pixel 7a > chất lượng hiển thị > tốt hơn;iphone 13 > google pixel 7a > màn hình > chất lượng hiển thị tốt hơn;
# =====
# samsung pixel 7a > iphone 13 > kích thước > lớn hơn;google pixel 7a > iphone 13 > màn hình > có kích thước > lớn hơn;
# ---------
# màn hình chiếc flagship của google > iphone 13 > kích thước > lớn hơn;chiếc flagship của google > iphone 13 > màn hình > kích thước lớn hơn;
# =====
# iphone 13 > iphone 13 > độ phân giải cao hơn rất nhiều;iphone 13 > iphone 13 > hệ thống camera trên google pixel 7 > độ phân giải cao hơn rất nhiều;
# ---------
# google pixel 7 > iphone 13 > hệ thống camera > độ phân giải cao hơn rất nhiều;hệ thống camera trên google pixel 7 > iphone 13 > độ phân giải > cao hơn rất nhiều;
# =====
# ios 16 > android 13 trên google pixel 7a > nhiều tính năng hấp dẫn hơn;iphone 13 > android 13 trên google pixel 7a > hệ điều hành ios 16 > nhiều tính năng hấp dẫn hơn;
# ---------
# hệ điều hành ios 16 > android 13 > tính năng > hấp dẫn hơn;iphone 13 > google pixel 7a > hệ điều hành > nhiều tính năng hấp dẫn hơn;
# =====
# galaxy z flip và z fold 2 > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế giới smartphone > phần còn lại của thế gi
# ---------
# galaxy z flip > phần còn lại của thế giới smartphone > unknow > khác hẳn;z fold 2 > phần còn lại của thế giới smartphone > unknow > khác hẳn;
# =====
# các chiếc z fold 2 > cụm camera đôi của z flip > vẻ gọn gàng hơn;cụm camera đôi của z flip > cụm camera đôi của z flip > vẻ gọn gàng hơn;
# ---------
# z flip > z fold 2 > cụm camera đôi > gọn gàng hơn;z flip > z fold 2 > cụm camera đôi > không “ bành chướng ” như;
# =====
# các nhà sản xuất khác > unknow > unknow > không giống như các nhà sản xuất khác;google > unknow > unknow > không giống như các nhà sản xuất khác;
# ---------
# google > iphone > mô-đun camera > hoàn toàn khác;google > các nhà sản xuất khác > unknow > không giống;
# =====
# samsung > unknow > cảm giác cầm nắm bằng một tay thoải mái hơn;iphone 13 > unknow > unknow > unknow > cảm giác cầm nắm bằng một tay thoải mái hơn;
# ---------
# iphone 13 > pixel 6 > unknow > nhỏ gọn hơn;iphone 13 > pixel 6 > cảm giác cầm nắm bằng một tay > thoải mái hơn;
# =====
# các đầu đọc dấu vân tay trong màn hình > tốc độ làm tươi cao hơn;đầu đọc dấu vân tay > trong màn hình > tốc độ làm tươi cao hơn;
# ---------
# unknow > unknow > tốc độ làm tươi > cao hơn;unknow > unknow > kích thước > lớn hơn;
# =====
# huawei 12 > iphone 12 > khả năng chống bụi/nước > tốt hơn;iphone 12 > iphone 12 > unknow > chất liệu > tốt hơn;
# ---------
# iphone 12 > mi 11 > chất liệu > độ bền tốt hơn;chất liệu trên iphone 12 > unknow > độ bền > tốt hơn;
# =====
# xiaomi mi 11 > unknow > màn hình hiển thị > tốt hơn;xiaomi mi 11 > unknow > unknow > tấm nền > tốt hơn;
# ---------
# xiaomi mi 11 > unknow > màn hình hiển thị > tốt hơn;xiaomi mi 11 > unknow > tấm nền > tốt nhất trên thị trường hiện nay;
# =====
# những vi xử lý thế hệ mới nhất hiện nay;cả hai model > hiệu năng > khá tương đồng nhau;
# ---------
# cả hai model > cả hai model > những vi xử lý thế hệ mới nhất hiện nay > đều được nhà sản xuất trang bị;cả hai model > cả hai model > hiệu năng > khá tương đồng nhau;
# =====
# ios 14 > unknow > dung lượng ram > thấp hơn;iphone 12 > unknow > unknow > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu hóa đến từ hệ điều hành ios 14 > tối ưu
# ---------
# iphone 12 > đối thủ của nó > dung lượng lượng ram > thấp hơn;iphone 12 > đối thủ của nó > hiệu suất > tương đương;
# =====
# Iphone 12 > unknow > dung lượng 2.815 mah >'lép vế'hơn hẳn đôi thủ của mình;iphone 12 > unknow > unknow >'lép vế'hơn hẳn đôi thủ của mình;
# ---------
# iphone 12 > đôi thủ của mình > viên pin >'lép vế'hơn hẳn;viên pin của iphone 12 > đôi thủ của mình > dung lượng >'lép vế'hơn hẳn;
# =====
# nếu xét tổng thể > iphone 12 > các thông số nhỏ hơn;iphone 12 > các thông số nhỏ hơn;
# ---------
# iphone 12 > mi 11 > màn hình > các thông số nhỏ hơn;iphone 12 > mi 11 > lượng tiêu hao năng lượng > ít hơn;
# =====
# <extra_id_0> > unknow > những đối thủ ở cùng tầm giá > vượt trội;điện thoại > unknow > những thông số vượt trội;
# ---------
# điện thoại > những đối thủ ở cùng tầm giá > thông số > vượt trội;điện thoại > những đối thủ ở cùng tầm giá > unknow > được đánh giá cao so với;
# =====
# galaxy a32 > camera trước > độ phân giải cao hơn 20 mp;galaxy a32 > camera trước > độ phân giải cao hơn 20 mp;
# ---------
# galaxy a32 > galaxy a33 > camera trước > có phần nhỉnh hơn;galaxy a32 > unknow > độ phân giải > cao hơn;
# =====
# samsung galaxy j8 > samsung galaxy j8 > độ phân giải cao hơn;oppo f9 > samsung galaxy j8 > samsung galaxy j8 > kích thước màn hình > lớn hơn;
# ---------
# oppo f9 > samsung galaxy j8 > kích thước màn hình > lớn hơn;oppo f9 > samsung galaxy j8 > độ phân giải > cao hơn;
# =====
# samsung j8 > samsung j8 > dung lượng > gấp đôi;oppo f9 > ram > gần như gấp đôi;
# ---------
# oppo f9 > samsung j8 > ram > gần như gấp đôi dung lượng;oppo f9 > samsung j8 > rom > gần như gấp đôi dung lượng;
# =====
# samsung j8 > unknow > thông số > gần bằng nhau;samsung j8 > unknow > thông số > gần bằng nhau;
# ---------
# oppo f9 > samsung j8 > thiết kế camera kép ở phía sau > đều được;oppo f9 > samsung j8 > thông số > gần bằng nhau;
# =====
# các sản phẩm công nghệ hãng oppo > các sản phẩm công nghệ hãng oppo > camera trước > tốt hơn;các sản phẩm công nghệ hãng oppo > tài chính > tốt hơn;
# ---------
# các các sản phẩm công nghệ hãng oppo > unknow > cấu hình > cao hơn;các các sản phẩm công nghệ hãng oppo > unknow > camera trước > tốt hơn;
# =====
# galaxy a03s > bộ 3 camera đa chức năng có độ phân giải > thấp hơn;camera sau của galaxy a03s > bộ 3 camera đa chức năng có độ phân giải > thấp hơn;
# ---------
# galaxy a03s > unknow > camera sau > độ phân giải thấp hơn;camera sau của galaxy a03s > unknow > độ phân giải > thấp hơn;
# =====
# samsung galaxy a13 4gb > samsung galaxy a03s > ram > lớn gấp đôi;samsung galaxy a13 4gb > samsung galaxy a03s > galaxy a03s > galaxy a03s > galaxy a03s > galaxy a03s > ram > lớn gấp đôi;
# ---------
# samsung galaxy a13 4gb > samsung galaxy a03s > ram 4 gb > đều có;galaxy a13 4gb > galaxy a03s > rom > lớn gấp đôi;
# =====
# <extra_id_0> > unknow > cảm giác cầm nắm > trở nên thuận tiện hơn rất nhiều;
# ---------
# unknow > unknow > cảm giác cầm nắm > thuận tiện hơn rất nhiều;unknow > unknow > sử dụng một tay > thuận tiện hơn rất nhiều;
# =====
# samsung galaxy s22 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > con chip mạnh mẽ nhất của qualcomm > thời điểm hiện tại: snapdragon 8 gen 1 > unknow > mạnh mẽ nhất của qualcomm > ở
# ---------
# samsung galaxy s22 > unknow > con chip > mạnh mẽ nhất của qualcomm ở thời điểm hiện tại;snapdragon 8 gen 1 > unknow > unknow > mạnh mẽ nhất của qualcomm ở thời điểm hiện tại;
# =====
# s22 > s22 > mức tiêu thụ điện là không giống nhau;s22 > s22 > thời gian sử dụng > ít hơn;
# ---------
# s22 > unknow > thời gian sử dụng > không có nghĩa là thời gian sử dụng của s22 sẽ ít hơn;s22 > unknow > mức tiêu thụ điện > không giống nhau;
# =====
# galaxy s22 > unknow > thời gian sạc > nhanh hơn;galaxy s22 > unknow > viên pin > có dung lượng thấp hơn;
# ---------
# galaxy s22 > unknow > viên pin > dung lượng thấp hơn;galaxy s22 > unknow > thời gian sạc > nhanh hơn;
# =====
# , iphone 13 > thế hệ trước > kích thước nhỏ gọn hơn một chút;iphone 13 > iphone 13 > thế hệ trước > thiết kế mặt trước > kích thước nhỏ gọn hơn một chút;
# ---------
# iphone 13 > thế hệ trước > thiết kế mặt trước > cải tiến nhỏ;iphone 13 > thế hệ trước > phần notch > kích thước nhỏ gọn hơn một chút;
# =====
# các điện thoại này > cả hai điện thoại này > khung viền nhôm > được vát phẳng và mặt lưng kính bóng bẩy phía sau;cả hai điện thoại này > khung viền nhôm > được vát phẳng và mặt lưng kính bóng bẩy phía sau;
# ---------
# cả hai điện thoại này > cả hai điện thoại này > khung viền nhôm được vát phẳng > đều sở hữu;cả hai điện thoại này > cả hai điện thoại này > mặt lưng kính bóng bẩy phía sau > đều sở hữu;
# =====
# samsung > unknow > các bộ xử lý cao cấp nhất;samsung > unknow > unknow > các bộ xử lý cao cấp nhất;
# ---------
# mẫu điện thoại cao cấp tiếp theo của samsung > unknow > bộ xử lý > cao cấp nhất qualcomm ở thời điểm hiện tại;snapdragon 8 gen 2 > unknow > unknow > cao cấp nhất qualcomm ở thời điểm hiện tại;
# =====
# samsung > cảm biến chính > kích thước > lớn hơn;iphone 13 của mình > khả năng nhiếp ảnh > cải thiện chất lượng ảnh thiếu sáng > tương tự;
# ---------
# iphone 13 > thế hệ trước > hệ thống camera kép > tương tự;iphone 13 > thế hệ trước > cảm biến chính > kích thước lớn hơn;
# =====
# galaxy s mới > iphone 14 pro max > lợi thế hơn;iphone 14 pro max > iphone 14 pro max > galaxy s mới > sạc đầy > mất nhiều thời gian hơn;
# ---------
# galaxy s mới > iphone 14 pro > sạc có dây > lợi thế hơn;galaxy s mới > iphone 14 pro > sạc có dây > lợi thế hơn;
# =====
# galaxy s23 + > galaxy s23 ultra > thời gian sạc > nhanh hơn;galaxy s23 ultra > galaxy s23 ultra > galaxy s23 ultra > thời gian sạc > nhanh hơn;
# ---------
# unknow > galaxy s23 + > thời gian sạc > nhanh hơn;unknow > galaxy s23 ultra > thời gian sạc > nhanh hơn;
# =====
# 82 0
